# %%
import ssms
from matplotlib import pyplot as plt
from ssms.basic_simulators import simulator
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import ssms
#       2 from matplotlib import pyplot as plt
#       3 from ssms.basic_simulators import simulator
#
# File /oscar/home/azhan378/ssm-simulators/ssms/__init__.py:3
#       1 import importlib.metadata
# ----> 3 from . import basic_simulators
#       4 from . import dataset_generators
#       5 from . import config
#
# File /oscar/home/azhan378/ssm-simulators/ssms/basic_simulators/__init__.py:3
#       1 from . import boundary_functions
#       2 from . import drift_functions
# ----> 3 from . import simulator
#       4 from . import theta_processor
#       5 from .simulator_class import Simulator
#
# File /oscar/home/azhan378/ssm-simulators/ssms/basic_simulators/simulator.py:16
#      13 from numpy.random import default_rng
# ...
